# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Bogotá, Colombia', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-e2202eb2b225> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Bogotá, Colombia', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Lisboa, Portugal', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-c8f9f0d12044> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Lisboa, Portugal', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Lisbon, Portugal', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-e857c5e5821c> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Lisbon, Portugal', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('California, USA', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/miniconda3/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/miniconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# ~/miniconda3/lib/python3.6/http/client.py in getresponse(self)
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Bogotá, Colombia', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-e2202eb2b225> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Bogotá, Colombia', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Modena, Italy', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Bogotá', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-6bc5244c178d> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Bogotá', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Bogota', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-547f8d270575> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Bogota', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Bogotá D.C., Colombia', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-36a185ce2133> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Bogotá D.C., Colombia', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Bogotá, Bogotá D.C., Colombia', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-b5f4fd332270> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Bogotá, Bogotá D.C., Colombia', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Bogotá, Cundinamarca, Colombia', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Lisbon, Lisbon, Portugal', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d7d51a8d09e7> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Lisbon, Lisbon, Portugal', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Bogotá, Distrito Capital de Bogotá, Colombia', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-362bd18c69e4> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Bogotá, Distrito Capital de Bogotá, Colombia', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Bogotá, Bogotá District Capital, Colombia', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-c635cffb041a> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Bogotá, Bogotá District Capital, Colombia', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Edinburg, Scotland', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-c7fbc814786f> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Edinburg, Scotland', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Edinburgh, Scotland', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-f9d9dda23343> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Edinburgh, Scotland', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Edinburg', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-3664636b258e> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Edinburg', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('Edinburgh', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-954b47950cea> in <module>()
#       1 import osmnx as ox
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 G = ox.graph_from_place('Edinburgh', network_type='drive')
#       4 fig, ax = ox.plot_graph(ox.project_graph(G))
#
# ~/miniconda3/lib/python3.6/site-packages/osmnx/core.py in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, name, which_result, buffer_dist, timeout, memory, max_query_area_size, clean_periphery, infrastructure)
#    1590     # create graph using this polygon(s) geometry
#    1591     G = graph_from_polygon(polygon, network_type=network_type, simplify=simplify, retain_all=retain_all,
# ...

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_place('London', network_type='drive')
fig, ax = ox.plot_graph(ox.project_graph(G))

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_address('Bogotá, Colombia', distance=15000)
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# /Users/AndreCNF/miniconda3/lib/python3.6/site-packages/osmnx/utils.py:268: RuntimeWarning: invalid value encountered in arccos
#   arc = np.arccos(cos)

# %%
import osmnx as ox
# %matplotlib inline
G = ox.graph_from_address('Bogotá, Colombia', distance=20000)
fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# /Users/AndreCNF/miniconda3/lib/python3.5/site-packages/osmnx/utils.py:268: RuntimeWarning: invalid value encountered in arccos
#   arc = np.arccos(cos)

# %%
ox.save_graphml(G, filename='BogotaNetwork2.graphml')

# %%
fig, ax = ox.plot_graph(ox.project_graph(G), dpi = 300)

# %%
fig.savefig('GrafoBogota.png', format='png', dpi=300)

# %%
extended_stats = ox.extended_stats(G, bc=True)
print(extended_stats['betweenness_centrality_avg'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-77b4c846665b> in <module>()
# ----> 1 extended_stats = ox.extended_stats(G, bc=True)
#       2 print(extended_stats['betweenness_centrality_avg'])
#
# NameError: name 'ox' is not defined

# %%
import networkit
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-72c757e930cf> in <module>()
# ----> 1 import networkit
#
# ImportError: No module named 'networkit'

# %%
ls
# Out:
# 1612.06115.pdf
# Abstract Andre.docx
# Analisis_Delitos_10_A_os.csv
# Data-driven_Estimation_of_Origin-Destination_Deman.pdf
# Grafo1 de Bogota.png
# GrafoBogota.eps
# GrafoBogota.png
# Rutas Inteligentes en la Ciudad de Bogotá Utilizando el Concepto de Complex Networks.pdf
# SEGURIDAD_VERTs.txt
# SSRN-id2943038.pdf
# Seguridad Bogota.xlsx*
# Untitled.ipynb
# Untitled1.ipynb
# boeing-osmnx-street-networks.pdf
# bogota_colombia.imposm-shapefiles/
# bogota_colombia.imposm-shapefiles.zip
# data/
# deviprasad_rao1.pdf
# images/
# tr-2004-24.pdf
# ~$stract Andre.docxx

# %%
os.chdir("/Users/AndreCNF/OneDrive/UNAL/Optimización y Control en Sistemas Distribuidos en Red/Proyecto/data/networkit")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2502bed139e8> in <module>()
# ----> 1 os.chdir("/Users/AndreCNF/OneDrive/UNAL/Optimización y Control en Sistemas Distribuidos en Red/Proyecto/data/networkit")
#
# NameError: name 'os' is not defined

# %%
import sys
print (sys.version)
# Out:
# 3.5.4 | packaged by conda-forge | (default, Aug 10 2017, 01:41:15)
# [GCC 4.2.1 Compatible Apple LLVM 6.1.0 (clang-602.0.53)]

# %%
import NetworKit
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-0ff2dff10964> in <module>()
# ----> 1 import NetworKit
#
# ImportError: No module named 'NetworKit'
